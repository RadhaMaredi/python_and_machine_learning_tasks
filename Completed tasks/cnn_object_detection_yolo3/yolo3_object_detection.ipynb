# %% [markdown]
# <a href="https://colab.research.google.com/github/RadhaMaredi/python_task_programs/blob/master/Completed%20tasks/cnn_object_detection_yolo3/yolo3_object_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/MyDrive/yolo3_custom_data'
# Out:
# backup	   chart_yolov3_cutom.png  custom_data.zip  darknet
# chart.png  custom_data		   custom_weight

# %%
#!unzip '/content/drive/MyDrive/yolo3_custom_data/custom_data.zip' -d '/content/drive/MyDrive/yolo3_custom_data/'

# %%
# !git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/MyDrive/yolo3_custom_data/darknet'
# Out:
# fatal: destination path '/content/drive/MyDrive/yolo3_custom_data/darknet' already exists and is not an empty directory.

# %%
# %cd /content/drive/MyDrive/yolo3_custom_data/darknet
# Out:
# /content/drive/MyDrive/yolo3_custom_data/darknet

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	json_mjpeg_streams.sh  scripts
# backup		darknet_images.py	LICENSE		       src
# build		darknet.py		Makefile	       vcpkg.json
# build.ps1	darknet_video.py	net_cam_v3.sh	       video_yolov3.sh
# cfg		data			net_cam_v4.sh	       video_yolov4.sh
# cmake		image_yolov3.sh		obj
# CMakeLists.txt	image_yolov4.sh		README.md
# darknet		include			results

# %%
# %cd darknet
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !make
# Out:
# [Errno 20] Not a directory: 'darknet'
# /content/drive/MyDrive/yolo3_custom_data/darknet
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ...

# %%
#create a make directory or to complile the model
#!make
# Out:
# chmod +x *.sh

# %%
#creating training and testing dataset
# %cd /content/drive/MyDrive/yolo3_custom_data
# Out:
# /content/drive/MyDrive/yolo3_custom_data

# %%
# !ls
# Out:
# backup	   chart_yolov3_cutom.png  custom_data.zip  darknet
# chart.png  custom_data		   custom_weight

# %%
# !python custom_data/creating-files-data-and-name.py

# %%
# !python custom_data/creating-train-and-test-txt-files.py

# %%
# !ls
# Out:
# backup	   chart_yolov3_cutom.png  custom_data.zip  darknet
# chart.png  custom_data		   custom_weight

# %%
# !darknet/darknet detector train custom_data/labelled_data.data darknet/cfg/yolov3_cutom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# yolov3_cutom
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 3, batch = 30, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...
